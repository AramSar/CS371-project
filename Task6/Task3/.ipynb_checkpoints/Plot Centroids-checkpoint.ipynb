# %%
import numpy 
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Task 2
centr2 = pd.read_csv("../Task2/Task2_179-11.csv")
# Task 3
centr3 = pd.read_csv("../Task3/Task3_centroids.csv")

# %%
plt.scatter(centr2["X"], centr2["Y"], label="Task2 centroids")
plt.scatter(centr3["X"], centr3["Y"], label="Task3 centroids")
plt.legend()
plt.ylim(500,100)
# plt.savefig("./Task3_centroids.jpg", dpi=300)
